# %% [markdown]
# ## Imports

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os

# %% [markdown]
# ## Pull the Data

# %%
income_df = pd.read_csv('2023StateIncome.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19408\1143259650.py in <module>
# ----> 1 income_df = pd.read_csv('2023StateIncome.csv')
#
# c:\Users\cwils\anaconda3\envs\PythonData\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     674         )
#     675
# ...

# %%
homeValue_df = pd.read_csv('Data/yearlyStateValue.csv')
homeValue_df['state'] = homeValue_df['RegionName']

# %% [markdown]
# ## Merge DataFrames on State

# %%
combined_df = pd.merge(income_df, homeValue_df, on='state', how='inner')

# %% [markdown]
# ## Select necessary rows

# %%
clean_df = combined_df[['state','2023','HouseholdIncome']]
clean_df['HomeValue'] = combined_df['2023']
# Out:
# c:\Users\cwils\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                    state       2023  HouseholdIncome  HomeValue
# 0   District of Columbia  727374.27            90842  727374.27
# 1               Maryland  387271.13            87063  387271.13
# 2             New Jersey  451762.17            85245  451762.17
# 3          Massachusetts  562322.30            84385  562322.30
# 4                 Hawaii  971229.63            83173  971229.63
# 5            Connecticut  370657.20            79855  370657.20
# 6             California  739948.48            78672  739948.48
# 7          New Hampshire  434838.45            77923  434838.45
# ...

# %% [markdown]
# ## Create affordability row and write to csv

# %%
clean_df['affordability'] =   clean_df['HomeValue'] / clean_df['HouseholdIncome']
clean_df.drop(columns='2023')
clean_df.sort_values('state')
clean_df.to_csv('Data/clean2023Data.csv', index=False)
# Out:
# c:\Users\cwils\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
